# %% [markdown]
# ---
#
# **<font color="green">Комментарий ревьюера</font>**
#
# Привет Сергей, меня зовут Созонтов Толя! Я ревьюер твоего проекта.
#
# Ты проделал большую работу. Нашел много интересных инсайтов и сделал несколько контринтуитивных выводов, молодец :)
#
# Извини, пожалуйста, за долгую проверку.
#
# По ходу тетрадки ты найдешь комментарии к проекту, они будут в отдельных ячейках Markdown с заголовком «Комментарий ревюера» + номер итерации проверки (v2, v3 ...). Постарайся учесть эти комментарии для дальнейших проектов.
#
# Пожалуйста, не удаляй комментарии.
#
# ---
#
#
#
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий ревьюера
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное :)
# </div>
#
# ---

# %% [markdown]
# # Принятие решений в бизнесе на основе данных.
#
# # Приоритезация гипотез.
#
# # A/B тест.

# %% [markdown]
# ## Оглавление

# %% [markdown]
# 1. [Описание проекта](#step1)
# 2. [Краткий план выполнения работы](#step2)
# 3. [Описание данных](#step3)
# 4. [Импорт библиотек](#step4)
# 5. [Загрузить данные и подготовите их к анализу](#step5)
#     - 5.1. [Работаем с таблицей - hypotheses](#step6)
#     - 5.1. [Работаем с таблицей - orders](#step7)
#     - 5.1. [Работаем с таблицей - visitors](#step8)
#     - 5.1. [Общий вывод по подготовке данных](#step9)
# 6. [Часть 1. Приоритизация гипотез](#step10)
#     - 6.1. [Фреймворк ICE для приоритизации гипотез](#step11)
#     - 6.2. [Фреймворк RICE для приоритизации гипотез](#step12)
#     - 6.3. [Вывод по части 1](#step13)
# 7. [Часть 2. Анализ A/B-теста](#step14)
#     - 7.1. [график кумулятивной выручки по группам](#step15)
#     - 7.2. [график кумулятивного среднего чека по группам](#step16)
#     - 7.3. [график относительного изменения кумулятивного среднего чека группы B к группе A](#step17)
#     - 7.4. [график кумулятивной конверсии по группам](#step18)
#     - 7.5. [график относительного изменения кумулятивной конверсии группы B к группе A](#step19)
#     - 7.6. [точечный график количества заказов по пользователям](#step20)
#     - 7.7. [95-й и 99-й перцентили количества заказов на пользователя](#step21)
#     - 7.8. [точечный график стоимостей заказов](#step22)
#     - 7.9. [95-й и 99-й перцентили стоимости заказов](#step23)
#     - 7.10. [статистическую значимость различий в конверсии между группами по «сырым» данным](#step24)
#     - 7.11. [статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным](#step25)
#     - 7.12. [статистическую значимость различий в конверсии между группами по «очищенным» данным](#step26)
#     - 7.13. [статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным](#step27)
#     - 7.14. [решение по результатам теста](#step28)
# 7. [Общий вывод](#step29)

# %% [markdown]
# ## Описание проекта <a id="step1"></a>
# </div>

# %% [markdown]
# Вместе с отделом маркетинга мы подготовили список гипотез для увеличения выручки.
#
# Приоритизируем гипотезы, запустим A/B-тест и проанализируем результаты.

# %% [markdown]
# ## Краткий план выполнения работы <a id="step2"></a>
# </div>

# %% [markdown]
# ### Часть 1. Приоритизация гипотез.

# %% [markdown]
# В файле /datasets/hypothesis.csv 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
#
# **Задача**
# - Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета;
# - Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета;
# - Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.

# %% [markdown]
# ### Часть 2. Анализ A/B-теста

# %% [markdown]
# Вы провели A/B-тест и получили результаты, которые описаны в файлах /datasets/orders.csv и /datasets/visitors.csv.
#
# **Задача**
# - Построить график кумулятивной выручки по группам. Сделайте выводы и предположения;
# - Построить график кумулятивного среднего чека по группам. Сделайте выводы и предположения;
# - Построить график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения;
# - Построить график кумулятивной конверсии по группам. Сделайте выводы и предположения;
# - Построить график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения;
# - Построить точечный график количества заказов по пользователям. Сделайте выводы и предположения;
# - Построить 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей;
# - Построить точечный график стоимостей заказов. Сделайте выводы и предположения;
# - Посчитать 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов;
# - Посчитать статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения;
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения;
# - Посчитать статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения;
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения;
# - Примите решение по результатам теста и объясните его. Варианты решений:
#         1. Остановить тест, зафиксировать победу одной из групп;
#         2. Остановить тест, зафиксировать отсутствие различий между группами;
#         3. Продолжить тест.

# %% [markdown]
# ## Описание данных <a id="step3"></a>
# </div>

# %% [markdown]
# **Данные для первой части:**
#
# Файл /datasets/hypothesis.csv.
# - Hypothesis — краткое описание гипотезы;
# - Reach — охват пользователей по 10-балльной шкале;
# - Impact — влияние на пользователей по 10-балльной шкале;
# - Confidence — уверенность в гипотезе по 10-балльной шкале;
# - Efforts — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
#
# **Данные для второй части:**
#
# Файл /datasets/orders.csv.
# - transactionId — идентификатор заказа;
# - visitorId — идентификатор пользователя, совершившего заказ;
# - date — дата, когда был совершён заказ;
# - revenue — выручка заказа;
# - group — группа A/B-теста, в которую попал заказ.
#
# Файл /datasets/visitors.csv.
# - date — дата;
# - group — группа A/B-теста;
# - visitors — количество пользователей в указанную дату в указанной группе A/B-теста

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Отлично, контекст понятен. Очень подробная декомпозиция проведена, молодец.
# </div>
#
# ---

# %% [markdown]
# ## Импорт библиотек <a id="step4"></a>
# </div>

# %%
#импортируем библиотеки
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import datetime as dt
import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу <a id="step5"></a>
# </div>

# %%
hypotheses = pd.read_csv('/datasets/hypothesis.csv')
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %%
#напишем функцию для первого взгляда на данные
def df_firstView(df):
    print('--------------------------------------------------')
    print('Размер набора данных (строк, столбцов):', df.shape)
    print('--------------------------------------------------')
    print('Количество грубых дубликатов в наборе данных:', df.duplicated().sum())
    print('--------------------------------------------------')
    print('Наименование столбцов:', df.columns)
    print('--------------------------------------------------')
    print('Просмотр типов данных в столбцах')
    print('--------------------------------------------------')
    df.info()
    print('')
    print('--------------------------------------------------')
    #print('Вывод случайных 20 строк набора данных')    
    #print('--------------------------------------------------')
    #print(df.sample(20))

# %% [markdown]
# #### Работаем с таблицей - hypotheses  <a id="step6"></a>
# </div>

# %%
#посмотрим информацию о таблице при помощи ранее созданной функции
df_firstView(hypotheses)
# Out:
# --------------------------------------------------
# Размер набора данных (строк, столбцов): (9, 5)
# --------------------------------------------------
# Количество грубых дубликатов в наборе данных: 0
# --------------------------------------------------
# Наименование столбцов: Index(['Hypothesis', 'Reach', 'Impact', 'Confidence', 'Efforts'], dtype='object')
# --------------------------------------------------
# Просмотр типов данных в столбцах
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
# Hypothesis    9 non-null object
# Reach         9 non-null int64
# Impact        9 non-null int64
# Confidence    9 non-null int64
# Efforts       9 non-null int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes
#
# --------------------------------------------------

# %% [markdown]
# Данные в порядке, пропусков не обнаружено, типы данных соответвуют задачам.

# %% [markdown]
# #### Работаем с таблицей - orders  <a id="step7"></a>
# </div>

# %%
#посмотрим информацию о таблице при помощи ранее созданной функции
df_firstView(orders)
# Out:
# --------------------------------------------------
# Размер набора данных (строк, столбцов): (1197, 5)
# --------------------------------------------------
# Количество грубых дубликатов в наборе данных: 0
# --------------------------------------------------
# Наименование столбцов: Index(['transactionId', 'visitorId', 'date', 'revenue', 'group'], dtype='object')
# --------------------------------------------------
# Просмотр типов данных в столбцах
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
# transactionId    1197 non-null int64
# visitorId        1197 non-null int64
# date             1197 non-null object
# revenue          1197 non-null int64
# group            1197 non-null object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB
#
# --------------------------------------------------

# %% [markdown]
# Столбец date содержит сведения о дате и времени, но имеет тип object. Изменим формат данных.

# %%
orders['date'] = orders['date'].astype('datetime64[D]')
orders['date'] = orders['date'].map(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))
orders['date'] = orders['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
orders.info()
orders.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
# transactionId    1197 non-null int64
# visitorId        1197 non-null int64
# date             1197 non-null datetime64[ns]
# revenue          1197 non-null int64
# group            1197 non-null object
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 46.9+ KB
#     transactionId   visitorId       date  revenue group
# 0      3667963787  3312258926 2019-08-15     1650     B
# 1      2804400009  3642806036 2019-08-15      730     B
# 2      2961555356  4069496402 2019-08-15      400     A
# 3      3797467345  1196621759 2019-08-15     9759     B
# 4      2282983706  2322279887 2019-08-15     2308     B
# 5       182168103   935554773 2019-08-15     2210     B
# 6       398296753  2900797465 2019-08-15     1860     B
# 7      2626614568    78758296 2019-08-15     1044     A
# 8      1576988021   295230930 2019-08-15    13710     A
# ...

# %% [markdown]
# #### Работаем с таблицей - visitors <a id="step8"></a>
# </div>

# %%
#посмотрим информацию о таблице при помощи ранее созданной функции
df_firstView(visitors)
# Out:
# --------------------------------------------------
# Размер набора данных (строк, столбцов): (62, 3)
# --------------------------------------------------
# Количество грубых дубликатов в наборе данных: 0
# --------------------------------------------------
# Наименование столбцов: Index(['date', 'group', 'visitors'], dtype='object')
# --------------------------------------------------
# Просмотр типов данных в столбцах
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
# date        62 non-null object
# group       62 non-null object
# visitors    62 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB
#
# --------------------------------------------------

# %% [markdown]
# Столбец date содержит сведения о дате и времени, но имеет тип object. Изменим формат данных.

# %%
visitors['date'] = visitors['date'].astype('datetime64[D]')
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))
visitors['date'] = visitors['date'].map(lambda x: dt.datetime.strptime(x, '%Y-%m-%d'))
visitors.info()
visitors.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
# date        62 non-null datetime64[ns]
# group       62 non-null object
# visitors    62 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 1.6+ KB
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
# 5  2019-08-06     A       667
# 6  2019-08-07     A       644
# 7  2019-08-08     A       610
# 8  2019-08-09     A       617
# 9  2019-08-10     A       406
# 10 2019-08-11     A       718
# 11 2019-08-12     A       595
# 12 2019-08-13     A       748
# 13 2019-08-14     A       735
# 14 2019-08-15     A       628
# 15 2019-08-16     A       361
# 16 2019-08-17     A       412
# 17 2019-08-18     A       668
# 18 2019-08-19     A       502
# 19 2019-08-20     A       575

# %% [markdown]
# #### Общий вывод по подготовке данных <a id="step9"></a>
# </div>

# %% [markdown]
# Данные готовы для работы, критичных замечаний нет, пропусков и дубликатов не обнаружено, проведена работа по подготовке типов данных и названий столбцов для удобной и продуктивной работы.

# %% [markdown]
# Данные прочитали, изменили тип данных у столбцов с датами, выгрузка совершена корректно, даты совпадают.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Отличная работа, отдельно хочу отметить использованную тобой кастомную функцию. Домашние заготовки -- это всегда круто. Сокращает время от знакомства с данными до исследования.
#
# Предобработка проведена очень тщательно, молодец.
# </div>
#
# ---

# %% [markdown]
# ## Часть 1. Приоритизация гипотез <a id="step10"></a>
# </div>

# %% [markdown]
# - Применить фреймворк ICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# - Применить фреймворк RICE для приоритизации гипотез. Отсортировать их по убыванию приоритета.
# - Указать, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.

# %% [markdown]
# #### Применяем фреймворк ICE для приоритизации гипотез  <a id="step11"></a>
# </div>

# %%
hypotheses['ice'] = hypotheses['Impact'] * hypotheses['Confidence'] / hypotheses['Efforts']
hypotheses.sort_values(by='ice', ascending =False)
# Out:
#                                           Hypothesis  Reach  Impact  \
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 7  Добавить форму подписки на все основные страни...     10       7
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 1  Запустить собственную службу доставки, что сок...      2       5
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts        ice
# 8           9        5  16.200000
# 0           8        6  13.333333
# 7           8        5  11.200000
# 6           8        3   8.000000
# 2           7        3   7.000000
# 1           4       10   2.000000
# 5           2        3   1.333333
# ...

# %% [markdown]
# #### Применяем фреймворк RICE для приоритизации гипотез  <a id="step12"></a>
# </div>

# %%
hypotheses['rice'] = hypotheses['Reach'] * hypotheses['Impact'] * hypotheses['Confidence'] / hypotheses['Efforts']
hypotheses.sort_values(by='rice', ascending =False)
# Out:
#                                           Hypothesis  Reach  Impact  \
# 7  Добавить форму подписки на все основные страни...     10       7
# 2  Добавить блоки рекомендаций товаров на сайт ин...      8       3
# 0  Добавить два новых канала привлечения трафика,...      3      10
# 6  Показать на главной странице баннеры с актуаль...      5       3
# 8  Запустить акцию, дающую скидку на товар в день...      1       9
# 3  Изменить структура категорий, что увеличит кон...      8       3
# 1  Запустить собственную службу доставки, что сок...      2       5
# 5  Добавить страницу отзывов клиентов о магазине,...      3       2
# 4  Изменить цвет фона главной страницы, чтобы уве...      3       1
#
#    Confidence  Efforts        ice   rice
# 7           8        5  11.200000  112.0
# 2           7        3   7.000000   56.0
# 0           8        6  13.333333   40.0
# 6           8        3   8.000000   40.0
# 8           9        5  16.200000   16.2
# ...

# %% [markdown]
# #### Вывод по части 1 <a id="step13"></a>
# </div>

# %% [markdown]
# - По фреймворку ICE наибольшую оценку имели гпиотезы 8,0 и 7.
# - По фреймворку RICE наибольшую оценку имели гпиотезы 7,2 и 0.
#
# Это можно объяснить тем, что в случае фреймворка ICE мы не учитывем охват изменений.
#
# **В нашем случае наиболее приоритетными гипотезами будут 7, 2, 0.**

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
# Все расчеты верные, молодец!
# </div>
#
# ---

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
# А какой бы фреймворк ты бы презентовал коллегам и почему?
#
# </div>
#
# ---

# %% [markdown]
# upd. RICE так как в нем есть трудозатраты, команде важно не только знать но и чувсвтвовать силы. регулярная оценка идей с учетом трудозатрат, с обязательным фидбеком в конце отчетного периода, развивает хватку у команды и адекватную оценку трудозатрат на работу.

# %% [markdown]
# ## <font color=red> Часть 2. Анализ A/B-теста <a id="step14"></a>
# </div>

# %% [markdown]
# **Задача**
# - Построить график кумулятивной выручки по группам. Сделайте выводы и предположения.
# - Построить график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# - Построить график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# - Построить график кумулятивной конверсии по группам. Сделайте выводы и предположения.
# - Построить график относительного изменения кумулятивной конверсии группы B к группе A. Сделайте выводы и предположения.
# - Построить точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# - Построить 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# - Построить точечный график стоимостей заказов. Сделайте выводы и предположения.
# - Посчитать 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# - Посчитать статистическую значимость различий в конверсии между группами по «сырым» данным. Сделайте выводы и предположения.
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# - Посчитать статистическую значимость различий в конверсии между группами по «очищенным» данным. Сделайте выводы и предположения.
# - Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# - Примите решение по результатам теста и объясните его. Варианты решений:
#         1. Остановить тест, зафиксировать победу одной из групп.
#         2. Остановить тест, зафиксировать отсутствие различий между группами.
#         3. Продолжить тест.

# %% [markdown]
# #### Построим график кумулятивной выручки по группам <a id="step15"></a>
# </div>

# %%
#получим таблицу с кумулятивными значениями по дате и группам
#получим уникальные значения дат и групп
datesGroups = orders[['date','group']].drop_duplicates().sort_values(by=['date', 'group'])

#выводим кумулятивные показатели из orders
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(x['date'] >= orders['date'], x['group']==orders['group'])]\
.agg({'date':'max', 'group':'max', 'transactionId':'nunique', 'visitorId':'nunique', 'revenue':'sum'}), axis = 1)
ordersAggregated.columns = ['date', 'group', 'orders', 'buyers', 'revenue']

#выводим кумулятивные показатели из visitors
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(x['date'] >= visitors['date'], x['group']==visitors['group'])]\
.agg({'date':'max', 'group':'max', 'visitors':'sum'}), axis = 1)

#сводим все накопительные данные в одну таблицу
cummulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group'])
cummulativeData.head(5)
# Out:
#         date group  orders  buyers  revenue  visitors
# 0 2019-08-01     A      24      20   148579       719
# 1 2019-08-01     B      21      20   101217       713
# 2 2019-08-02     A      44      38   242401      1338
# 3 2019-08-02     B      45      43   266748      1294
# 4 2019-08-03     A      68      62   354874      1845

# %%
#построим график кумулятивной выручки по группам
cummulativeDataA = cummulativeData[cummulativeData['group']=='A']
cummulativeDataB = cummulativeData[cummulativeData['group']=='B']
plt.figure(figsize=(18,8))
plt.grid(axis = 'x')
plt.plot(cummulativeDataA['date'], cummulativeDataA['revenue'], label = 'A')
plt.plot(cummulativeDataB['date'], cummulativeDataB['revenue'], label = 'B')
plt.ylabel('Выручка')
plt.xlabel('Дата')
plt.title('График кумулятивной выручки по группам A/B')
plt.legend()
plt.show()

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# Чтобы предупреждения библиотек не отвлекали, обрати внимание на библиотеку `warnings`. Например, простая фильтрация предупреждений - `warnings.simplefilter("ignore")`
# </div>
#
# ---

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# Очень полезный стандартный метод `plt.grid`. Он выводит сетку на график для удобства сопоставления значений по осям.
# </div>
#
# ---

# %% [markdown]
# Исходя из информации представленной на графике видно, что группа B стабильно показывает большую выручку чем группа A, практически с начала теста не отпускает лидерство.
#
# В районе даты - 2019-08-17 наблюдается резкий скачок.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# Какие бы гипотезы ты выдвинул на основании графика и скачка в районе 17.08?
# </div>
#
# ---

# %% [markdown]
# upd. гипотеза по резкому скачку, выброс, скорее всего там крупная покупка: не типичная для настоящего набора данных: нарушает логику графика, он должен плавно уходить вверх.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера V2
#
# Совершенно верно. В подобных исследования можно сразу рассматривать графики и по грязным по чистым данным для наглядности.
# </div>
#
# ---

# %% [markdown]
# #### Построим график кумулятивного среднего чека по группам <a id="step16"></a>
# </div>

# %%
plt.figure(figsize=(18,8))
plt.grid(axis = 'x')
plt.plot(cummulativeDataA['date'], cummulativeDataA['revenue']/cummulativeDataA['orders'], label = 'A')
plt.plot(cummulativeDataB['date'], cummulativeDataB['revenue']/cummulativeDataB['orders'], label = 'B')
plt.title('Графики кумулятивного среднего чека по группам A/B')
plt.ylabel('Средний чек')
plt.xlabel('Дата')
plt.legend()
plt.show()

# %% [markdown]
# График в целом похож на график представленный выше, аналогично группа В в лидерах, лишь на 2019-08-13 упускает первое место, но не надолго, так же в глаза бросается резкий скачок 2019-08-17, здесь он выглядит еще "круче".

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# График выше после 19.08 очень похож на так называемое "возвращение к среднему". Обычно возникает из-за единовременных мощных выбросов.
#
# </div>
#
# ---

# %% [markdown]
# #### Построим график относительного изменения кумулятивного среднего чека группы B к группе A <a id="step17"></a>
# </div>

# %%
mergedCummulativeData = cummulativeDataA.merge(cummulativeDataB, left_on='date', right_on='date', suffixes=['A', 'B'])
mergedCummulativeData.head(5)
plt.figure(figsize=(18,6))
plt.grid(axis = 'x')
plt.plot(mergedCummulativeData['date'], ((mergedCummulativeData['revenueB']/mergedCummulativeData['ordersB'])/
                                       (mergedCummulativeData['revenueA']/mergedCummulativeData['ordersA'])-1))
plt.axhline(y=0, color='black', linestyle = '--')
plt.title('График относительного изменения кумулятивного среднего чека группы B к группе A')
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# По графику трудно сделать вывод, амплитуда колебаний слишком большая, работаем дальше.

# %% [markdown]
# #### Построим график кумулятивной конверсии по группам <a id="step18"></a>
# </div>

# %%
mergedCummulativeData['conversionA'] =  mergedCummulativeData['ordersA'] / mergedCummulativeData['visitorsA'] 
mergedCummulativeData['conversionB'] =  mergedCummulativeData['ordersB'] / mergedCummulativeData['visitorsB']
mergedCummulativeData.head(5)
plt.figure(figsize=(18,5))
plt.grid(axis = 'x')
plt.plot(mergedCummulativeData['date'], mergedCummulativeData['conversionA'], label='A')
plt.plot(mergedCummulativeData['date'], mergedCummulativeData['conversionB'], label='B')
plt.title('График кумулятивной конверсии по группам A/B')
plt.xlabel('Дата')
plt.ylabel('Конверсия')
plt.legend()
plt.show()

# %% [markdown]
# Кумулятивная конверсия в период начала теста относительная схожа, дальше группа В стабильно начинает показывать лучшие результыты. Группа А падает до низких значений и не поднимается.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
#
# График выше -- это классный пример того, что в АВ тестах не стоит делать преждевременных выводов. Например, если бы бизнес дал нам всего неделю на исследование, то в таком случае, выводы были бы крайне сомнительными. Необходимо аргументированно донести до заказчика, что кумулятивные метрики не "стабилизировались" и необходимо продолжить тест.
# </div>
#
# ---

# %% [markdown]
# #### Построим график относительного изменения кумулятивной конверсии группы B к группе A <a id="step19"></a>
# </div>

# %%
mergedCummulativeData.head(5)
plt.figure(figsize=(18,4))

plt.plot(mergedCummulativeData['date'], ((mergedCummulativeData['conversionB']/
                                          mergedCummulativeData['conversionA'])-1))
plt.title('График относительного изменения кумулятивной конверсии группы B к группе A')
plt.axhline(y=0, color='black', linestyle='--')
plt.axhline(y=0.1, color='grey', linestyle='--')
plt.xlabel('Дата')
plt.show()

# %% [markdown]
# После того как тест набрал обороты, по прошествии первых 7 дней, конверсия в группе B стабильно лучше конверсии в группе A на порядка 10%.

# %% [markdown]
# #### Построим точечный график количества заказов по пользователям <a id="step20"></a>
# </div>

# %%
orders.head(5)
ordersByUsers = orders.groupby('visitorId', as_index = False).agg({'transactionId':'nunique'}).sort_values(by='transactionId', ascending = False)
ordersByUsers.columns = ['visitorId', 'orders']
ordersByUsers.head(5)
plt.figure(figsize=(18,4))
plt.grid(axis = 'x')
plt.hist(ordersByUsers['orders'], bins = 10)
plt.title('Гистрограмма распределения количества заказов на одного пользователя')
plt.show()

x_values = pd.Series(range(0, len(ordersByUsers)))
plt.figure(figsize=(18,4))
plt.grid(axis = 'x')
plt.scatter(x_values, ordersByUsers['orders'])
plt.title('Точечная диаграмма числа заказов на одного пользователя')
plt.show()

# %% [markdown]
# Абсолютное большинство клиентов не совершает больее 1-2 заказов.

# %% [markdown]
# #### Посчитаем 95-й и 99-й перцентили количества заказов на пользователя. Выберем границу для определения аномальных пользователей <a id="step21"></a>
# </div>

# %%
percentiles = np.percentile(ordersByUsers['orders'], [95, 99])
print('Перцентили:\n95: {}\n99: {}'.format(percentiles[0],percentiles[1]))
# Out:
# Перцентили:
# 95: 2.0
# 99: 4.0

# %% [markdown]
# Можно сделать вывод что больше 2 заказов совершают только 5% пользователей.

# %% [markdown]
# #### Построим точечный график стоимостей заказов <a id="step22"></a>
# </div>

# %%
plt.figure(figsize=(18,5))
plt.grid(axis = 'x')
plt.hist(orders['revenue'], range=(0,100000), bins = 100)
plt.title('Гистрограмма распределения сумм заказов на одного пользователя')
plt.show()

x_values = pd.Series(range(0, len(orders)))
plt.figure(figsize=(18,5))
plt.grid(axis = 'x')
plt.scatter(x_values, orders['revenue'])
plt.title('Точечная диаграмма сумм заказов на одного пользователя')
plt.axis([0, 1200, 0, 200000])
plt.show()

# %% [markdown]
# По информации на графиках, делаем вывод - в абсолютном большинстве покупки стоимостью до 25 тыс. руб.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Комментарий ревьюера
#
# В целом все верно, но из за ограничения в отображении ты визуально пропускаешь нарушителей кумулятивных метрик :) Это не критично, так как ты отрезаешь выбросы далее по выбранному процентилю далее.
# </div>
#
# ---

# %% [markdown]
# #### Посчитаем 95-й и 99-й перцентили сумм заказов на пользователя. Выберем границу для определения аномальных пользователей <a id="step23"></a>
# </div>

# %%
percentiles = np.percentile(orders['revenue'], [95, 99])
print('Перцентили:\n95: {:.0f}\n99: {:.0f}'.format(percentiles[0],percentiles[1]))
# Out:
# Перцентили:
# 95: 28000
# 99: 58233

# %% [markdown]
# Делаем вывод - порядка 5% заказов дороже 28 т.р.

# %% [markdown]
# #### Посчитаем статистическую значимость различий в конверсии между группами по «сырым» данным <a id="step24"></a>
# </div>

# %% [markdown]
# Сформируем гипотезы для проверки статистичееской значимости различий в конверсии между группами:
# - **Н0:** по неочищенным данным разницы в конверсии групп A и B нет ;
# - **Н1:** по неочищенным данным в конверсии групп A и B разница статистически значима.

# %%
ordersByUsersA = orders[orders['group']=='A'].groupby('visitorId', as_index=False).agg({'transactionId':'nunique'})
ordersByUsersA.columns = ['visitorId', 'orders']
ordersByUsersB = orders[orders['group']=='B'].groupby('visitorId', as_index=False).agg({'transactionId':'nunique'})
ordersByUsersB.columns = ['visitorId', 'orders']
print('Кол-во покупателей в группе A: {}'.format(len(ordersByUsersA)))
print('Кол-во покупок в группе А: {}'.format(ordersByUsersA['orders'].sum()))
print('Кол-во посетителей в группе A: {}\n'.format(visitors[visitors['group']=='A']['visitors'].sum()))
print('Кол-во покупателей в группе B: {}'.format(len(ordersByUsersB)))
print('Кол-во покупок в группе B: {}'.format(ordersByUsersB['orders'].sum()))
print('Кол-во посетителей в группе B: {}'.format(visitors[visitors['group']=='B']['visitors'].sum()))


#составим списки кол-ва заказов sampleA и sampleB со всеми пользователями (в том числе и не купившими) по группам 
list_orders_1 =[]
for i in range(0,(visitors[visitors['group']=='A']['visitors'].sum()-len(ordersByUsersA))):
    list_orders_1.append(0)
orders_by_non_purchased_users_A = pd.Series(data = list_orders_1, name = 'orders')

list_orders_2 =[]
for i in range(0,(visitors[visitors['group']=='B']['visitors'].sum()-len(ordersByUsersB))):
    list_orders_2.append(0)
orders_by_non_purchased_users_B = pd.Series(data = list_orders_2, name = 'orders')

sampleA = pd.concat([ordersByUsersA['orders'], orders_by_non_purchased_users_A], axis=0)
sampleB = pd.concat([ordersByUsersB['orders'], orders_by_non_purchased_users_B], axis=0)
print('\nОтносительный прирост конверсии группы B по отношению к группе A: {:.3f}'.format(sampleB.mean()/sampleA.mean()-1))
alpha = 0.05
results = stats.mannwhitneyu(sampleA, sampleB)
print('P-value: {}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по неочищенным данным в конверсии групп A и B разница статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, по неочищенным данным разницы в конверсии групп A и B нет')
# Out:
# Кол-во покупателей в группе A: 503
# Кол-во покупок в группе А: 557
# Кол-во посетителей в группе A: 18736
#
# Кол-во покупателей в группе B: 586
# Кол-во покупок в группе B: 640
# Кол-во посетителей в группе B: 18916
#
# Относительный прирост конверсии группы B по отношению к группе A: 0.138
# P-value: 0.008396177528376304
# Отвергаем нулевую гипотезу: по неочищенным данным в конверсии групп A и B разница статистически значима

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Отлично, преобразования верные. Статистический тест выбран корректно, молодец
# </div>
#
# ---

# %% [markdown]
# ---
#
#
#
# <div class="alert alert-block alert-danger">
#
#
# ### Комментарий ревьюера
#
# Очень важный момент, сформулируй, пожалуйста, нулевую и альтернативную гипотезу. Не совсем понятно, что именно мы не отвергаем или отвергаем.
#
# Это поможет тебе сориентироваться в тех случаях когда гипотез станет в разы больше, также для общения с заказчиком, чтобы у вас было одинаковое представление о происходящих вычислениях.
# </div>
#
# ---

# %% [markdown]
# ---
#
#
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера v2
#
# Отлично, теперь вычисления стали прозрачными, даже для самого далекого от аналитики заказчика.
# </div>
#
# ---

# %% [markdown]
# #### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным <a id="step25"></a>
# </div>

# %% [markdown]
# Сформируем гипотезы для проверки статистичееской значимости в среднем чеке между группами:
# - **Н0:** по неочищенным данным разницы в среднем чеке групп A и B нет ;
# - **Н1:** по неочищенным данным в среднем чеке групп A и B разница статистически значима.

# %%
print('Относительное изменение среднего чека в группе B по отношению группы A: {:.3f}'.format(
orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
results = stats.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])
print('P-value: {}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по неочищенным данным разница в средних чеках в группах A и B статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, по неочищенным данным разницы в средних чеках групп A и B нет')
# Out:
# Относительное изменение среднего чека в группе B по отношению группы A: 0.259
# P-value: 0.3646454927716229
# Не получилось отвергнуть нулевую гипотезу, по неочищенным данным разницы в средних чеках групп A и B нет

# %% [markdown]
# #### Посчитаем статистическую значимость различий в конверсии между группами по «очищенным» данным <a id="step26"></a>
# </div>

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Расчеты так же верные.
#
# </div>
#
# ---

# %% [markdown]
# Очистим данные от пользователей, с превышающими установленные нами лимиты значениями:
# - количество покупок - 2;
# - сумма заказа - 28 т. руб.

# %%
#задаем лимиты
limit_orders = 2 #количество покупок
limit_revenue = 28000 #сумма заказа

usersWithManyOrders = pd.concat([ordersByUsersA[ordersByUsersA['orders']>limit_orders]['visitorId'], 
                                ordersByUsersB[ordersByUsersB['orders']>limit_orders]['visitorId']], axis = 0)
usersWithExpensiveOrders = orders[orders['revenue']>limit_revenue]['visitorId']
abnormalUsers = pd.concat([usersWithManyOrders, 
                           usersWithExpensiveOrders], axis = 0).drop_duplicates().sort_values()

print('Кол-во аномальных пользователей: {}'.format(len(abnormalUsers)))
# Out:
# Кол-во аномальных пользователей: 74

# %% [markdown]
# Сформируем гипотезы для проверки статистической значимости в конверсии между группами:
# - **Н0:** по очищенным данным разницы в конверсии групп A и B нет ;
# - **Н1:** по очищенным данным в конверсии групп A и B разница статистически значима.

# %%
sampleAFiltered = pd.concat([
    ordersByUsersA[np.logical_not(ordersByUsersA['visitorId'].isin(abnormalUsers))]['orders'],
    orders_by_non_purchased_users_A
], axis = 0)
sampleBFiltered = pd.concat([
    ordersByUsersB[np.logical_not(ordersByUsersB['visitorId'].isin(abnormalUsers))]['orders'],
    orders_by_non_purchased_users_B
], axis = 0)

print('\nОтносительный прирост конверсии группы B по отношению к группе A после очистки данных: {:.3f}'.format(sampleBFiltered.mean()/sampleAFiltered.mean()-1))

results = stats.mannwhitneyu(sampleAFiltered, sampleBFiltered)

print('P-value: {}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по очищенным данным в конверсии групп A и B статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, по очищенным данным разницы в конверсии групп A и B нет')
# Out:
# Относительный прирост конверсии группы B по отношению к группе A после очистки данных: 0.173
# P-value: 0.006521296371518379
# Отвергаем нулевую гипотезу: по очищенным данным в конверсии групп A и B статистически значима

# %% [markdown]
# #### Посчитаем статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным <a id="step27"></a>
# </div>

# %% [markdown]
# Сформируем гипотезы для проверки статистической значимости в среднем чеке между группами:
# - **Н0:** по очищенным данным разницы в среднем чеке групп A и B нет ;
# - **Н1:** по очищенным данным в среднем чеке групп A и B разница статистически значима.

# %%
print('Относительное изменение среднего чека в группе B по отношению группы A после очистки данных: {:.3f}'.format(
orders[np.logical_and(orders['group']=='B', np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'].mean()\
/orders[np.logical_and(orders['group']=='A', np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'].mean()-1))
       
       
results = stats.mannwhitneyu(orders[np.logical_and(orders['group']=='A', np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'],
                             orders[np.logical_and(orders['group']=='B', np.logical_not(orders['visitorId'].isin(abnormalUsers)))]['revenue'])
print('P-value: {}'.format(results.pvalue))
if results.pvalue < alpha:
    print('Отвергаем нулевую гипотезу: по очищенным данным разница в средних чеках в группах A и B статистически значима')
else:
    print('Не получилось отвергнуть нулевую гипотезу, по очищенным данным разницы в средних чеках в группах A и B нет')
# Out:
# Относительное изменение среднего чека в группе B по отношению группы A после очистки данных: -0.020
# P-value: 0.3692408756572825
# Не получилось отвергнуть нулевую гипотезу, по очищенным данным разницы в средних чеках в группах A и B нет

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Комментарий ревьюера
#
# Отлично, проверка на очищенных данных также проведена идеально.
#
# Сформулируй, пожалуйста и для двух тестов выше H0 и H1
# </div>
#
# ---

# %% [markdown]
# ## Примем решение по результатам теста  <a id="step28"></a>
# </div>

# %% [markdown]
# Варианты принимаемых решений:
#
# 1. Остановить тест, зафиксировать победу одной из групп.
# 2. Остановить тест, зафиксировать отсутствие различий между группами.
# 3. Продолжить тест.
#
# Принимаемое решение - **Остановить тест, зафиксировать победу одной из групп** - <font color=red>**победа группы В**
#
# <font color=black>**Обоснование принятого решения**
# - кумулятивные метрики по выручке, среднему чеку и конверсии почти все время лидировали в группе B.
# - до очистки данных показатель конверсии в группе B больше показателя в группе A на 14%;
# - после очистки данных показатель конверсии в группе B больше показателя в группе A на 17%;
# - разница в показателях конверсии является статистически значимой.

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-warning">
#
#
# ### Общий комментарий ревьюера v1
#
# Сергей, ты проделал большую работу, молодец! Критичные замечания только в оформлении, очень жаль возвращать проект по формальной причине
#
# * Сформулируй H0 и H1 для каждого статистического теста.
# * Собери, пожалуйста, все инсайты по проекту в том числе и приоритизация гипотез в общий вывод.
#
# Поправь пожалуйста "красные" замечания по ходу проекта, если хочешь подумай над "желтыми"  и присылай его на финальную итерацию, удачи!
#
# </div>
#
# ---

# %% [markdown]
# # Общий вывод  <a id="step29"></a>
# </div>

# %% [markdown]
# Цель настоящей работы - поиск пути по увеличению выручки интернет-магазина.
#
# Быил выполнены следующие задачи:
# - приоритизация гипотез 2мя фреймворками;
# - проанализировали результаты A/B-тест.
#
#
# Выводы по этапу приоретизации гипотез:
# - По фреймворку ICE наибольшую оценку имели гпиотезы 8,0 и 7.
# - По фреймворку RICE наибольшую оценку имели гпиотезы 7,2 и 0.
#
# Это можно объяснить тем, что в случае фреймворка ICE мы не учитывем охват изменений.
# В нашем случае наиболее приоритетными гипотезами будут 7, 2, 0.
#
#
# Выводы по этапу - Анализ A/B-теста:
#
# Принимаемое решение - **Остановить тест, зафиксировать победу одной из групп** - <font color=red>**победа группы В**
#
# <font color=black>Обоснование принятого решения:
# - кумулятивные метрики по выручке, среднему чеку и конверсии почти все время лидировали в группе B.
# - до очистки данных показатель конверсии в группе B больше показателя в группе A на 14%;
# - после очистки данных показатель конверсии в группе B больше показателя в группе A на 17%;
# - разница в показателях конверсии является статистически значимой.
#
# **На основании вышеизложенного можно сделать выво о том, что гипотезы собранные в группе B способны статистически значимо повлиять пололжительно на выручку интернет-магазина.**

# %% [markdown]
# ---
#
# <div class="alert alert-block alert-success">
#
#
# ### Общий комментарий ревьюера v2
#
# Большое спасибо за проработанные комментарии. Критичных замечаний у меня нет.
#
# Поздравляю с завершенным исследованием. Успехов в дальнейшем обучении!
#
# </div>
#
# ---
