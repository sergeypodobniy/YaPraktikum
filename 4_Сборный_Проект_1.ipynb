# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Привет! Очень рад, что ты уже почти закончил 1 этап Практикума!) Спасибо, что сдал задание:) Ты проделал большую работу. Далее в файле мои комментарии ты сможешь найти в ячейках, аналогичных данной ( если рамки комментария зелёные - всё сделано правильно; жёлтые - есть замечания, но не критично; красные - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выпфолнения проекта.
#
# </div>

# %% [markdown]
# # Выявление закономерностей определяющих успешность компьютерной игры

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Мы работаем на интернет-магазин «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation).
#
# Нам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
#
# Исходная информация - данные до 2016 года.
# Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными.
# Не важно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ## Описание данных

# %% [markdown]
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы долларов)
# - EU_sales — продажи в Европе (миллионы долларов)
# - JP_sales — продажи в Японии (миллионы долларов)
# - Other_sales — продажи в других странах (миллионы долларов)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board).

# %% [markdown]
# ## Краткий план выполнения работы

# %% [markdown]
# 1. Шаг 1. Ознакомление с данными и их подготовка.
#     - заменить названия столбцов (привести к нижнему регистру);
#     - преобразовать данные в нужные типы; описать, в каких столбцах заменили тип данных и почему;
#     - обработать пропуски при необходимости; объяснить, почему заполнили пропуски определённым образом или почему не стали это делать;
#     - опишисать причины, которые могли привести к пропускам;
#     - обратить внимание на аббревиатуру 'tbd' в столбцах с рейтингом;разобрать это значение и описать, как его обработать;
#     - посчитать суммарные продажи во всех регионах и записать их в отдельный столбец.
#
#
# 2. Шаг 2. Исследовательский анализ данных.
#     - посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#     - посмотреть, как менялись продажи по платформам. Выбрать платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы? Взять данные за соответствующий актуальный период; Актуальный период определить в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год. Не учитывать в работе данные за предыдущие годы;
#     - какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ;
#     - построить график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Опишите результат;
#     - посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы;
#     - соотнести выводы с продажами игр на других платформах;
#     - посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
#
# 3. Шаг 3. Составление портрета пользователя каждого региона.
# Определить для пользователя каждого региона (NA, EU, JP):
#     - выделить самые популярные платформы (топ-5). Описать различия в долях продаж.
#     - выделить самые популярные жанры (топ-5). Пояснить разницу.
#     - влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
#
# 4. Шаг 4. Проверка гипотез.
#     - средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#     - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные;
#     - задать пороговое значение alpha.
#     - пояснить как формулировалась нулевая и альтернативная гипотезы; какой критерий применен для проверки гипотез и почему.
#
#
# 5. Шаг 5. Общий вывод.

# %% [markdown]
# ## 1. Шаг 1. Ознакомление с данными и их подготовка.
#     - заменить названия столбцов (привести к нижнему регистру);
#     - преобразовать данные в нужные типы; описать, в каких столбцах заменили тип данных и почему;
#     - обработать пропуски при необходимости; объяснить, почему заполнили пропуски определённым образом или почему не стали это делать;
#     - описать причины, которые могли привести к пропускам;
#     - обратить внимание на аббревиатуру 'tbd' в столбцах с рейтингом; разобрать это значение и описать, как его обработать;
#     - посчитать суммарные продажи во всех регионах и записать их в отдельный столбец.

# %%
#импорт библиотек используемых в проекте
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st
import seaborn as sns
import mplcursors

# %%
games = pd.read_csv('/datasets/games.csv', sep =',')

# %%
print('Размер набора данных games (строк, столбцов):', games.shape)
# Out:
# Размер набора данных games (строк, столбцов): (16715, 11)

# %% [markdown]
# Посмотрим на информацию о таблице и на случайные 20 записей в ней.

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# Name               16713 non-null object
# Platform           16715 non-null object
# Year_of_Release    16446 non-null float64
# Genre              16713 non-null object
# NA_sales           16715 non-null float64
# EU_sales           16715 non-null float64
# JP_sales           16715 non-null float64
# Other_sales        16715 non-null float64
# Critic_Score       8137 non-null float64
# User_Score         10014 non-null object
# Rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
games.sample(20)
# Out:
#                                                     Name Platform  \
# 13160  Nounai Aeshe: IQ Suppli DS 2 - Sukkiri King Ke...       DS
# 4330             Despicable Me: The Game - Minion Mayhem       DS
# 5808                                     TRON: Evolution     X360
# 14830                                Battlefield Vietnam       PC
# 16199                           LifeSigns: Surgical Unit       DS
# 9991                         Sphinx and the Cursed Mummy       XB
# 10367                            Woody Woodpecker Racing       PS
# 1804                                   Derby Stallion 99       PS
# 14232             Battle Assault 3 featuring Gundam Seed      PS2
# 8841                               Top Gun: Combat Zones       GC
# 16245     Hot Wheels: Stunt Track Challenge / World Race      GBA
# 9380                                     Transworld Surf       XB
# 5369                                 Marvel Super Heroes       PS
# ...

# %% [markdown]
# Наблюдения по первому взгляду.
# 1. Наименования столбцов различны по регистру.
# 2. Столбец year_of_release требует доработки, преведения к типа int, долей быть не должно.
# 3. Столбец critic_score содержит большое количество пропусков.
# 4. Столбец user_score имеет тип данных object, а содержит цифры, требуется приведение к float64. Так же в этом столбце большое количество пропусков и 2424 значения со странным содержанием "tbd". Мое основное предположение - это значение означает что рейтинг не присвоен, генерируется не пользователями в прямом смысле, возможно косвенно, например количество выставленных оценок не преодолело определенный порог, иными словами, оценок слишком мало.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Отличное начало, радует, что основательно подходишь к анализу с самого начала работы

# %%
# 1. приводим названия столбцов к единообразному виду и смотрим их намиенования
games.columns = games.columns.str.lower()
games.columns
# Out:
# Index(['name', 'platform', 'year_of_release', 'genre', 'na_sales', 'eu_sales',
#        'jp_sales', 'other_sales', 'critic_score', 'user_score', 'rating'],
#       dtype='object')

# %%
print('Первая игра в наборе данных вышла в', games['year_of_release'].min(), "г., "
      'последняя игра в', games['year_of_release'].max(), "г.")
# Out:
# Первая игра в наборе данных вышла в 1980.0 г., последняя игра в 2016.0 г.

# %% [markdown]
# ###### Работа с пропусками

# %% [markdown]
# Пропуски присутствуют в столбцах:
# - critic_score;
# - rating;
# - user_score;
# - year_of_release;
# - genre;
# - name.
#
#
# Разеберем каждый столбце отдельно:
#
# - **critic_score** - оценка критиков (максимум 100) - в нашем наборе данных большое количество игр, далеко не факт что каждая из них проходило ревизию у критиков, думаю по-этому мы и имеем такое кол-во пропусков, заполнять эти данные средним или медианой нельзя, возможно стоит рассмотреть среднее значение по году в котором игра выходила, возможно картину это не испортит, вернемся к этому вопросу позже, пока заменим пропуски значением **"0"**;
#
#
# - **rating** - рейтинг от ESRB - ситуация аналогично выше перечисленному, составить представления об игре и присвоить рейтинг задача не такая простая, особенно когда игр выходит за сезон большое количество, не каждая из них на слуху, могло не хватать времени, могло не хватать оценок, или просто игра прошла мимо рейтингового агенства, и не ясно когда агенство вооббще начало работать. Заполняем пропуски в этом столбце значением - **"no_rating"**;
#
#
# - **user_score** - оценка пользователей (максимум 10) - поступаем с этим столбцом, аналогично столбцу critic_score, пока заменим пропуски значением **"0"**. В наборе данных содержиться информация о игровой индустрии с 1980 по 2016 год, даже если и было где поставить рейтинг игре, или каким-то образом его посчитать, то платформы, которые бы агрегировали эти данные не существовали на протяжении обозначенного временного промежутка, они появились во втором промежутке периода.
#
#
# - **year_of_release** - год выпуска игры - пропусков мало, но они есть, значений насчитывается 269, возникли они вероятнее всего при заполнении базы данных человеком, либо второй вариант - трудности хранения и переноса данных, потерялись, закономерности не наблюдается, обрабатывать ми их не будем, за неимением данных в настоящем наборе;
#
#
# - **genre** - пропусков мало, но они есть, заменим их на значение **"0"**, затем посмотрим на них;
#
#
# - **name** - пропусков мало, но они есть, заменим их на значение **"0"**, затем посмотрим на них.

# %%
# обрабатываем пропуски
games['critic_score'] = games['critic_score'].fillna(0)
games['rating'] = games['rating'].fillna('no_rating')
games['user_score'] = games['user_score'].fillna(0)
#games['year_of_release'] = games['year_of_release'].fillna(1979)
games['genre'] = games['genre'].fillna(0)
games['name'] = games['name'].fillna(0)

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16715 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16715 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       16715 non-null float64
# user_score         16715 non-null object
# rating             16715 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Посмотрим на срез данных по значению 0 в столбце genre и name.

# %%
games.query('genre == 0')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659      0      GEN           1993.0     0      1.78      0.53      0.00
# 14244    0      GEN           1993.0     0      0.00      0.00      0.03
#
#        other_sales  critic_score user_score     rating
# 659           0.08           0.0          0  no_rating
# 14244         0.00           0.0          0  no_rating

# %% [markdown]
# Посчитаем продажи во всех регионах  и запишем данные в отдельный столбец.

# %%
games.query('name == 0')
# Out:
#       name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659      0      GEN           1993.0     0      1.78      0.53      0.00
# 14244    0      GEN           1993.0     0      0.00      0.00      0.03
#
#        other_sales  critic_score user_score     rating
# 659           0.08           0.0          0  no_rating
# 14244         0.00           0.0          0  no_rating

# %% [markdown]
# Изначально было подозрение о парности этих пропусков, они подтвердились.

# %% [markdown]
# Оставляем значения "0" в столбцах  этих столбцах без изменений year_of_release, genre и name.

# %%
#запустив это, можно увидеть количество "tbd"
games['user_score'].value_counts().head()
# Out:
# 0      6701
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# Name: user_score, dtype: int64

# %% [markdown]
# Приведем данные в порядок в соответствии с наблюдениями.

# %%
# 2. year_of_release к типу данных int
#games['year_of_release'] = games['year_of_release'].astype('int')

# 3. critic_score и другие пропуски рассмотрим далее

# 4. user_score к типу данных float64 и замена tbd на NaN
games['user_score'] = games['user_score'].replace('tbd', np.NaN)
games['user_score'] = games['user_score'].astype('float')

# %% [markdown]
# Посчитаем суммарные продажи во всех регионах и запишем их в отдельный столбец.

# %%
games['total_sales'] = games['na_sales'] + games['eu_sales'] + games['jp_sales'] + games['other_sales']

# %% [markdown]
# В завершении раздела проверим данные на дубликаты.

# %%
# проверим количество грубых дубликатов
print('Количество грубых дубликатов в наборе данных:', games.duplicated().sum())
# Out:
# Количество грубых дубликатов в наборе данных: 0

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Данные предобработали и разобрались с неточностями, отлично, можно приступать и к анализу

# %% [markdown]
# ## 2. Шаг 2. Исследовательский анализ данных.
#     - посмотреть, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
#     - посмотреть, как менялись продажи по платформам, выбрать платформы с наибольшими суммарными продажами и постройте распределение по годам, за какой характерный срок появляются новые и исчезают старые платформы?
#     - определить актульный период в результате исследования предыдущих вопросов, эти данные помогут построить прогноз на 2017 год;
#     - какие платформы лидируют по продажам, растут или падают? Выбрать несколько потенциально прибыльных платформ;
#     - построить график «ящик с усами» по глобальным продажам каждой игры и разбивкой по платформам. Велика ли разница в продажах? А в средних продажах на разных платформах? Описать результат;
#     - посмотреть, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы;
#     - соотнести выводы с продажами игр на других платформах;
#     - посмотреть на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
def draw(groupby_column, func, y='name'):
    df = games.groupby(groupby_column)[y]
    if func == 'count':
        df_calculated = df.count()
        figsize = (18,5)
        plot = df_calculated.plot(kind='bar', y=y, figsize=figsize, color='orange')
    elif func == 'sum':
        df_calculated = df.sum().sort_values()
        figsize = (18,10)
        plot = df_calculated.plot(kind='barh', y=y, figsize=figsize, color='green')

# %% [markdown]
# ##### <font color=red> Посмотрим, сколько игр выпускалось в разные годы.

# %%
 draw('year_of_release', 'count')

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <h1 style="color:orange; margin-bottom:20px">Комментарий наставника</h1>
#
# Абсолютно не понятно, что за зависимость изображена на графике, никогда не забывай подписывать оси на графиках и сам график

# %% [markdown]
# До середины 90х игр выпускалось крайне мало, после график начинает расти, в 2002 резкий рост, 2008 и 2009 пик производства игр, далее идет на спад, интересно было бы наложить сюда график роста соц сетей, и рост он-лайн игровых решений.
#
#
# **Важны ли данные за все периоды?** Думаю для нашего исследования важны данные начиная с 1991 г. Совсем откинуть период 1991-1993 нельзя, так как в период становления индустрии здесь могли выходить игры, ставшие потом бессмертной классикой.

# %% [markdown]
# ##### <font color=red> Посмотрим, как менялись продажи по платформам.

# %% [markdown]
# Посмотрим на лидеров среди платформ по выручке.

# %%
draw('platform', 'sum', 'total_sales')

# %% [markdown]
# Лидерство PS2 для людей кто хоть немного знаком с игровой индустрией не удивительно, на данный момент это самая продаваемая консоль в мире. А по всему списку можно выделить 6 платформ, их выручка значительно выше группы отстающих, между PS и GBA разница более чем в 2 раза.
#
# Посмотрим на то, сколько игр было выпущено для каждой из платформ.

# %%
draw('platform', 'count')

# %% [markdown]
# На этом рисунке сходятся гиганты индустрии, PS2 от Sony и DS от Nintendo, количество игр идентично, дальше группы из платформ, но все это почти в 2 раза меньше чем у лидеров.

# %% [markdown]
# Выделим в отдельную таблицу лидеров по выручке среди платформ.

# %%
top_platforms = ['PS2', 'X360', 'PS3', 'Wii', 'DS', 'PS']

# %% [markdown]
# Для построения графика который поможет нам ответить на вопрос как менялись продажи по платформам используем модуль - mplcursors

# %%
# напишем функцию для автоматизации построения графиков
# синтаксис подсмотрел в интернете, реализация очень понравилась, разобрал и взял на вооружение
def draw_lines(platforms=None, query=None):
   
    ax = plt.gca()
    legend_list = []
    if query == None:
        if platforms == None:
            bbox_y = 1.08
            legend_size = 7
            platforms = games['platform'].unique().tolist()
        else:
            platforms = platforms
            bbox_y = 0.97
            legend_size = 9
    else:
        platforms = games.query(query)['platform'].unique().tolist()
        bbox_y = 0.97
        legend_size = 9
        
    for platform in platforms:
        if query == None:
            df_to_plot = games.query('platform == @platform')
        else:
            df_to_plot = games.query('platform == @platform').query(query)
        lines = df_to_plot.groupby('year_of_release')['total_sales'].sum().plot(x='year_of_release', y='total_sales',
                                                                    style='.-', kind='line', fontsize=10,
                                                                    linewidth=1, label=platform, ax=ax, figsize=(15,5))
        legend_list.append(platform)
    
    ax.set_xlabel('')
   
    ax.legend(legend_list, prop={'size':legend_size}, bbox_to_anchor=(1.0, bbox_y))

# %%
draw_lines(platforms=top_platforms)

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <h1 style="color:orange; margin-bottom:20px">Комментарий наставника</h1>
#
# Над графиками в будущем точно нужно будет работать детальнее, по таким графикам ничего не понятно, а они призваны наоборот упрощать понимание проведённого анализа

# %% [markdown]
# Из графика можно сделать вывод о жизненном цикле платформ, выделенных нами в топ, а именно:
# - PS2 - 2000 - 2011 гг. - 11 лет;
# - X360 - 2005 - 2015 гг. - 10 лет;
# - PS3 - 2006 - 2016 гг. - 10 лет;
# - Wii - 2006 - 2015 гг. - 9 лет;
# - DS - 2004 - 2013 гг. - 9 лет;
# - PS - 1994 - 2003 гг. - 9 лет.
#
# Средний срок жизни одной платформы составляет 10 лет.

# %% [markdown]
# В нашем топе платорм, половина принадлежит одному производителю, это Sony. Давайте посмотрим на тот же график но только по платформам указанного производителя.

# %%
sony_platforms = ['PS2', 'PS3', 'PS']
draw_lines(platforms=sony_platforms)

# %% [markdown]
# На графике хорошо видно как одно поколение платформ сменяет другое, циклы в среднем по 10 лет, средний нахлест в 1-2 года. Смена PS2 на PS3 затянулась, это связано с уникальной успешностью платформы второго поколения, абсолютным бестселлером в индустрии.

# %% [markdown]
# ##### <font color=red> Определим актульный период в результате исследования предыдущих вопросов, для последующего прогноза на 2017 год

# %% [markdown]
# Исходя из графиков выше, для построения прогностической модели принято решения взять период с 2002 года по 2016. Нижняя граница взята с тем учетом, что на этот период приходится скачок в выпуске игр и одновременно на пике находится выручка по продажам для платформы PS2, пик формы этой консоли нельзя не учесть.
#
# Посмотрим на график в выбранном диапазоне.

# %%
draw_lines(query='year_of_release >= 2002')

# %% [markdown]
# К сожалению мы наблюдаем на графике "кризис жанра", график идет вниз, это в некотором роде печально, так как игровая индустрия дала миру много, в частности достижения игромира теперь используются при создании голивудских блокбастеров.
#
# На конец расчетного срока мы видим что в лидерах по прежнему Sony со своей **PS4**, Microsoft с **Xone** и Nintendo **3DS**, ниже располагается группа из платформ PS3, XBOX, PSV.

# %% [markdown]
# Выберем несколько потенциально прибыльных платформ - это будут Sony PS4, Microsoft Xone и Nintendo 3DS.

# %% [markdown]
# ##### <font color=red> Построить график размаха по глобальным продажам каждой игры и разбивкой по платформам.
#     Велика ли разница в продажах? А в средних продажах на разных платформах? Описать результат

# %% [markdown]
# Построим диаграмму размаха по общей выручке индустрии.

# %%
# напишем функцию для построения нужных нам диаграмм размаха
def draw_boxplot(title=None, query_condition = None, ylims=None):
    if query_condition == None:
        ax = games.boxplot(column='total_sales', fontsize=15, figsize=(15,5),
                                         boxprops=dict(),
                                         medianprops=dict(),
                                         whiskerprops=dict(),
                                         capprops=dict(), 
                                         notch=True)
    else:
        df_query = games.query(query_condition)
        by_column = query_condition.split()[0]
        ax = df_query.boxplot(column='total_sales', by=by_column, fontsize=15, figsize=(15,5),
                                         boxprops=dict(),
                                         medianprops=dict(),
                                         whiskerprops=dict(),
                                         capprops=dict(),
                                         notch=True)
        ax.set_xlabel('')
        ax.set_title('')
    if ylims != None:
        ax.set_ylim(ylims)
    if title != None:
        plt.suptitle(title, y=0.94, fontsize=15)

# %%
draw_boxplot(ylims=[0,2])

# %% [markdown]
# В основном продажи игр составляют до 1.1 млн. долларов, при медиане в около 1.8 млн.

# %% [markdown]
# Построим диагрммму размаха по наиболее популярным платформам, на конец 2016 года, которые мы выделили на прошлом этапе анализа.

# %%
draw_boxplot(query_condition="platform in @top_platforms", ylims=[0,2])

# %% [markdown]
# Верхняя граница на уровне 1,7 млн принадлежит двум платформам - PS3 и X360.
#
#
# Разброс медианы по платформам от 0,1 до 0,27 млн долларов прибыли за игру.

# %% [markdown]
# ##### <font color=red> Посмотрим, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков.
#
#     Построим диаграмму рассеяния и посчитаем корреляцию между отзывами и продажами.
#     Сформулируем вывод.
#     Соотнесем выводы с продажами игр на других платформах.

# %% [markdown]
# **Для работы сформируем данные по нескольким платформам лидера рынка (Sony) с отзывами критиков и построим диаграммы рассеяния.**

# %%
games_ps2_critic = games[(games['platform'] == 'PS2') & (games['critic_score'] > 0)].copy()
games_ps3_critic = games[(games['platform'] == 'PS3') & (games['critic_score'] > 0)].copy()
games_ps4_critic = games[(games['platform'] == 'PS4') & (games['critic_score'] > 0)].copy()

# %%
games_ps2_critic.plot(kind='scatter', x='critic_score', y='total_sales', color='orange', figsize=(10,6))

# %%
games_ps3_critic.plot(kind='scatter', x='critic_score', y='total_sales', color='orange', figsize=(10,6))

# %%
games_ps4_critic.plot(kind='scatter', x='critic_score', y='total_sales', color='orange', figsize=(10,6))

# %% [markdown]
# Все 3 графика говорят об одном, с увеличением рейтинга увеличивается выручка компании.

# %% [markdown]
# **Теперь сформируем данные по нескольким платформам лидера рынка (Sony) с отзывами пользователей и построим диаграммы рассеяния.**

# %%
games_ps2_user = games[(games['platform'] == 'PS2') & (games['user_score'] > 0)].copy()
games_ps3_user = games[(games['platform'] == 'PS3') & (games['user_score'] > 0)].copy()
games_ps4_user = games[(games['platform'] == 'PS4') & (games['user_score'] > 0)].copy()

# %%
games_ps2_user.plot(kind='scatter', x='critic_score', y='total_sales', color='green', figsize=(10,6))

# %%
games_ps3_user.plot(kind='scatter', x='critic_score', y='total_sales', color='green', figsize=(10,6))

# %%
games_ps4_user.plot(kind='scatter', x='critic_score', y='total_sales', color='green', figsize=(10,6))

# %% [markdown]
# Ситуация с отзывами пользователей аналогична с отзывами критиков, чем они выше тем больше денег это приносит.

# %% [markdown]
# **Приступим к кореляции между значениями.**
# Построим матрицу для наших наборов данных от лидера рынка (Sony) по платформам PS2, PS3 и PS4.

# %%
games_ps2_for_corr = games_ps2_user[['total_sales' ,'critic_score', 'user_score']]
plt.figure(figsize=(8,3))
sns.heatmap(games_ps2_for_corr.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
            annot=True, annot_kws={'size':15})

# %%
games_ps3_for_corr = games_ps3_user[['total_sales' ,'critic_score', 'user_score']]
plt.figure(figsize=(8,3))
sns.heatmap(games_ps3_for_corr.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
            annot=True, annot_kws={'size':15})

# %%
games_ps4_for_corr = games_ps4_user[['total_sales' ,'critic_score', 'user_score']]
plt.figure(figsize=(8,3))
sns.heatmap(games_ps4_for_corr.corr()[['total_sales']].sort_values(by='total_sales', ascending=False), 
            annot=True, annot_kws={'size':15})

# %% [markdown]
# ###### Ситуация на всех 3 платформах Sony идентична, на продажи в гораздо большей степени влияют оценки критиков, нежели оценки пользователей.

# %% [markdown]
# ##### <font color=red> Посмотрим на общее распределение игр по жанрам.
#
#     Что можно сказать о самых прибыльных жанрах?
#     Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# Нарисуем столбчатую гистограмму с указанием количества и суммой продаж по каждому жанру набора данных.

# %%
ax = plt.gca()
pivot = games.groupby('genre').agg({'name': 'count', 'total_sales': 'sum'}).sort_values(by='name', ascending=False)
plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='white', ax=ax, width=0.35, color='orange', position=1)
plot2 = pivot['total_sales']
plot2.plot(kind='bar', figsize=(15,5), ec='white', ax=ax, width=0.35, color='green', position=0)
ax.legend(['Количество продаж', 'Сумма продаж'])

# %% [markdown]
# Ожидаемо самый популярный жанр Action у игропроизводителей, за ним идут спортивные симуляторы и игры смешанного жанра.  Жанры файтинг, стратегии и пазл замыкают диаграмму.
#
# Интересно выглядит жанр Adventure, относительно много произведено, но сумма продаж не велика.
#
# Посмотрим на эти же данные, но только отсортированные по сумме продаж.

# %%
ax = plt.gca()
pivot = games.groupby('genre').agg({'name': 'count', 'total_sales': 'sum'}).sort_values(by='total_sales', ascending=False)
plot1 = pivot['name']
plot1.plot(kind='bar', figsize=(15,5), ec='white', ax=ax, width=0.35, color='orange', position=1)
plot2 = pivot['total_sales']
plot2.plot(kind='bar', figsize=(15,5), ec='white', ax=ax, width=0.35, color='green', position=0)
ax.legend(['Количество продаж', 'Сумма продаж'])

# %% [markdown]
# По сумме продаж "золотая" тройка собралась - экшен, спорт и шутер. При чем КПД  у шутера гораздо выше в этой тройке, дельта между произведено и заработано в тройке самая маленькая.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Платформы проанализированны и всё выполнено правильно, радует, что пишешь выводы! теперь можно посмотреть и на портреты пользователей по регионам

# %% [markdown]
# ## 3. Шаг 3. Составление портрета пользователя каждого региона.
# Определить для пользователя каждого региона (NA, EU, JP):
#     - выделить самые популярные платформы (топ-5). Описать различия в долях продаж.
#     - выделить самые популярные жанры (топ-5). Пояснить разницу.
#     - влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
# напишем функцию для выдачи заданных диаграмм
def draw_top_regions(groupby, region_sales, ax):
    pivot = games.groupby(groupby).agg({region_sales: 'sum'}).sort_values(by=region_sales, ascending=False)[:5]
    title_dict = {'na_sales': 'North America Sales', 'eu_sales': 'Europe Sales', 'jp_sales': 'Japan Sales'}
    color_dict = {'na_sales': None, 'eu_sales': 'gray', 'jp_sales': 'forestgreen'}
    plot = pivot.plot(kind='bar', ec='white', title=title_dict[region_sales], ax=axes[ax], 
                   fontsize=12, color=color_dict[region_sales], rot=20)
    plot.legend(prop={'size':15})
    plot.set_xlabel('')
    plot.title.set_size(20)

# %% [markdown]
# ##### <font color=red> Самые популярные платформы (топ-5) каждого региона (NA, EU, JP)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,4))

draw_top_regions('platform', 'na_sales', 0)
draw_top_regions('platform', 'eu_sales', 1)
draw_top_regions('platform', 'jp_sales', 2)

# %% [markdown]
# Где родился, там и пригодился, таков девиз наших диаграмм. В америке лидирует местный X360 от Microsoft, конечно Sony отстали совсем не сильно. В европейских странах рынок захвачен японским гигантом, PS2 и PS3 являются абсолютными лидерами, X360 проигрывает здесь заметно. В японии про X360 в топ-5 уже и не слышали, там есть свои ребята - платформы от Sony и Nintendo.
#
# Можно сделать вывод что целевым рынком Microsoft ялвялется северная америка, Sony европейский континет и домашняя арена, а Nintendo с своими платформами Wii, DS и 3DS, на домашней арене чувствует себя уверенно, а на выезде забирает то что останется от разборки гигантов.

# %% [markdown]
# ##### <font color=red> Самые популярные жанры каждого региона (NA, EU, JP)

# %%
fig, axes = plt.subplots(1, 3, figsize=(25,6))

draw_top_regions('genre', 'na_sales', 0)
draw_top_regions('genre', 'eu_sales', 1)
draw_top_regions('genre', 'jp_sales', 2)

# %% [markdown]
# Во вкусах Северной америки и Европы нет разницы, графики идентичны по смыслу за исключением одного жанра (Platform/Racing), Япония выделяется, Role-playing здесь лидер абсолютный, дальше ситуация больше похоже на ситуацию соседей.

# %% [markdown]
# ##### <font color=red> Влияет ли рейтинг ESRB на продажи в отдельном регионе (NA, EU, JP)

# %%
# создадим словарь с расшифровкой рейтингов и присвоим его в набор данных
ESRB_dict = {'E': 'Для всех', 'M': '> 17 лет', 'T': '13-19 лет', 'E10+': '>10 лет'}
games['ESRB_description'] = games[games['rating'].notnull()]['rating'].map(ESRB_dict)

#построим графики
fig, axes = plt.subplots(1, 3, figsize=(25,6))

draw_top_regions('ESRB_description', 'na_sales', 0)
draw_top_regions('ESRB_description', 'eu_sales', 1)
draw_top_regions('ESRB_description', 'jp_sales', 2)

# %% [markdown]
# Северная Америка и Европе вновь показывают идентичные результаты, в Японии пользовательи отдают больше предпочтения играм в категории 13-19 лет.

# %% [markdown]
# <div style="border:solid orange 2px; padding: 20px"> <h1 style="color:orange; margin-bottom:20px">Комментарий наставника</h1>
#
# Портреты пользователей построены, все выводы правильные,  но здесь стоило построить круговые диаграммы

# %% [markdown]
# ## 4. Шаг 4. Проверка гипотез.
#     - средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
#     - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные;
#     - пояснить как формулировалась нулевая и альтернативная гипотезы; какой критерий применен для проверки гипотез и почему.

# %% [markdown]
# Чтобы проверить гипотезу о равенстве среднего двух генеральных совокупностей по взятым из них выборкам, применяется метод scipy.stats.ttest_ind (array1, array2, equal_var).

# %% [markdown]
# #####  <font color=red> Гипотеза №1 - средние пользовательские рейтинги платформ Xbox One и PC одинаковые

# %% [markdown]
# H_0 - нулевая гипотеза - средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
#
# H_1 - альтернативная гипотеза - средние пользовательские рейтинги платформ Xbox One и PC различны.

# %%
rating_xbox = games[(games['platform'] == 'XOne') & (games['user_score'] > 0)]['user_score']
rating_PC = games[(games['platform'] == 'PC') & (games['user_score'] > 0)]['user_score']

print('Средний пользовательский рейтинг xbox - {:.2f}'.format(rating_xbox.mean()))
print('Средний пользовательский рейтинг PC - {:.2f}'.format(rating_PC.mean()))

alpha = .05
results_1 = st.ttest_ind(rating_xbox, rating_PC)
print('p-значение:', results_1.pvalue)
if (results_1.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Средний пользовательский рейтинг xbox - 6.52
# Средний пользовательский рейтинг PC - 7.06
# p-значение: 1.3896435533548819e-05
# Отвергаем нулевую гипотезу

# %% [markdown]
# Средние пользовательские рейтинги платформ Xbox One и PC отличаются между собой, нулевая гипотеза отвергается.

# %% [markdown]
# #####  <font color=red> Гипотеза №1 - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные

# %% [markdown]
# H_0 - альтернативная гипотеза - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») одинаковы.
#
# H_1 - нулевая гипотеза - средние пользовательские рейтинги жанров Action (англ. «действие») и Sports (англ. «виды спорта») разные.

# %%
rating_action = games[(games['genre'] == 'Action') & (games['user_score'] > 0)]['user_score']
rating_sports = games[(games['genre'] == 'Sports') & (games['user_score'] > 0)]['user_score']

print('Средний пользовательский рейтинг action - {:.2f}'.format(rating_action.mean()))
print('Средний пользовательский рейтинг sports - {:.2f}'.format(rating_sports.mean()))

alpha = .05
results_1 = st.ttest_ind(rating_action, rating_sports)
print('p-значение:', results_1.pvalue)
if (results_1.pvalue < alpha):
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# Средний пользовательский рейтинг action - 7.05
# Средний пользовательский рейтинг sports - 6.96
# p-значение: 0.10406951359049141
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Отвергнуть гипотезу не удалось, средние двух генеральных совокупностей равны.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Радует, что для проверки гипотез используешь правильные методы, вывода по результатам првоерки тоже правильные, молодец

# %% [markdown]
# ## 5. Шаг 5. Общий вывод.

# %% [markdown]
# Проделана работа по выявлению закономерностей влияющих на комерческую успешность компьютерной игры, основной фактор - оценка критика.
# Соответственно в дальнейшем следует выстраивать стратегию продвижения с этим учетом, необходимо налаживать работу с специализированными изданиями, блогерами. Так же для усиления эффекта, для продвижения не только игры но и платформы, нужна работа с экслюзивными играми для платформы, и повышению их рейтинга.
#
# Общая картина выглядит не радужно, рынок "падает", мобильные платформы забирают внимание пользователей, если быть точнее - смартфоны (несколько мобильных платформ представлено и в нашем наборе данных, но их доля очень мала). В этой ситуации возможно стоит пересмотреть подход к работе платформы в будующих поколениях, взгляд просится в сторону стриминговых сервисов, ведь тогда, пользователю нужен только сенсорный экран.

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Вывод покрывает все аспекты проделанной работы, супер

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px"> <h1 style="color:green; margin-bottom:20px">Комментарий наставника</h1>
#
# Ты проделал колоссальную работу и я очень рад за тебя! Удачи на следующем этапе!
