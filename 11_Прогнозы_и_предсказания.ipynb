# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий от ревьюера:</b>
#
# Сергей, добрый день! Меня зовут Влада. Проект выполнен прекрасно, ошибок нет :)
#
# Ниже в файле ты найдешь мои комментарии: <font color='green'>зеленый цвет — «все отлично»; </font> <font color='blue'>синий — «хорошо, но можно лучше (исправлять необязательно)»; </font> <font color='red'>красный — «нужно исправить».</font> Комментарии в самом коде я отделяю знаками «###».
#
# </div>

# %% [markdown]
# # Сеть фитнес-центров «Культурист-датасаентист».
#
# # Подготовка план действий по удержанию клиентов на основе проведенного анализа.

# %% [markdown]
# ## Оглавление

# %% [markdown]
# 1. [Описание проекта](#step1)
# 2. [Краткий план выполнения работы](#step2)
# 3. [Описание данных](#step3)
# 4. [Импорт библиотек](#step4)
# 5. [Шаг 1. Загрузка данных](#step5)
# 6. [Шаг 2. Исследовательский анализ данных (EDA)](#step6)
# 7. [Шаг 3. Модель прогнозирования оттока пользователей](#step7)
# 8. [Шаг 4. Кластеризация пользователей](#step8)
# 9. [Шаг 5. Выводы и базовые рекомендации по работе с клиентами](#step9)

# %% [markdown]
# ## Описание проекта <a id="step1"></a>
# </div>

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с пользователями на основе аналитических данных.
#
#
# Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что пользователь больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо.
#
#
# Индикаторы оттока зависят от специфики отрасли. Когда пользователь редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас.
# Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся.
#
#
# Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество анкет пользователей.
#
# **Наша задача — провести анализ и подготовить план действий по удержанию клиентов.**

# %% [markdown]
# ## Краткий план выполнения работы <a id="step2"></a>
# </div>

# %% [markdown]
# **Шаг 1. Загрузка данных**
# - Загрузка данных;
# - Предобработка данных.
#
# **Шаг 2. Проведение исследовательского анализа данных (EDA)**
# - Есть ли в наборе данных отсутствующие признаки, изучить средние значения и стандартные отклонения;
# - Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался;
# - Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - Построить матрицу корреляций и отобразите её.
#
#
# **Шаг 3. Построим модель прогнозирования оттока пользователей**
#
# Построим модель бинарной классификации пользователей, где целевой признак — факт оттока пользователя в следующем месяце:
#
# - Разбейте данные на обучающую и валидационную выборку.​
# - Обучите модель на train-выборке двумя способами:
#     - логистической регрессией
#     - случайным лесом.
# - Оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравнить по ним модели. Какая модель показала себя лучше на основании метрик?
#
#
#
# **Шаг 4. Сделаем кластеризацию пользователей**
# - Стандартизируйте данные;
# - Построим матрицу расстояний на стандартизованной матрице признаков и нарисуем дендрограмму;
# - Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируем кластеры клиентов;
# - Посмотрим на средние значения признаков для кластеров. Можно ли сразу что-то заметить?
# - Построим распределения признаков для кластеров. Можно ли что-то заметить по ним?
# - Для каждого полученного кластера посчитаем долю оттока. Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?
#
# **Шаг 5. Сформулируем выводы и сделаем базовые рекомендации по работе с клиентами**

# %% [markdown]
# ## Описание данных <a id="step3"></a>
# </div>

# %% [markdown]
# «Культурист-датасаентист» предоставил сведения в csv-файле.
# Путь к файлу: /datasets/gym_churn.csv.
#
# Заказчик подготовил данные, которые содержат данные на месяц до оттока и факт оттока на определённый месяц.
# Набор данных включает следующие поля:
# - 'Churn'​— факт оттока в текущем месяце;
# - Текущие поля в датасете:
#     - Данные пользователя за предыдущий до проверки факта оттока месяц:
#         - 'gender' - пол;
#         - 'near_location' - проживание или работа в районе, где находится фитнес-центр;
#         - 'partner' - сотрудник компании-партёра клуба;
#         - 'promo_friends' - факт первоначальной записи в рамках акции "приведи друга";
#         - 'phone' - наличие контактного телефона;
#         - 'age' - возраст;
#         - 'lifetime' - время с первого обращения в фитнесс-центр.
# - Информация на основе журнала посещений, покупок и информация о текущем статусе абонемента клиента:
#     - 'contract_period'- длительность текущего действующего аобнемента (месяц, 3 месяца, 6 месяцев, 1 год)*
#     - 'month_to_end_contract' - срок до окончания текущего действующего абонемента (в месяцах);
#     - 'group_visits' - факт посещения групповых занятий;
#     - 'avg_class_frequency_total' - средняя частота посещений в неделю за все время с начала действия абонемента;
#     - 'avg_class_frequency_current_month' - средняя частота посещений в неделю за предыдущий месяц;
#     - 'avg_additional_charges_total' - суммарная выручка от других услуг фитнес-центра: кафе, спорт-товары, косметический и массажный салон.

# %% [markdown]
# ## Импорт библиотек <a id="step4"></a>
# </div>

# %%
#импортируем библиотеки
import pandas as pd
import math as mth
import matplotlib.pyplot as plt
from scipy import stats as st
import numpy as np
import seaborn as sns; sns.set()
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_auc_score
from sklearn.cluster import KMeans
from scipy.cluster.hierarchy import dendrogram, linkage
pd.options.display.expand_frame_repr = False
import warnings
warnings.filterwarnings('ignore')

# %%
logs = pd.read_csv('/datasets/gym_churn.csv')

# %%
#напишем функцию для первого взгляда на данные
def df_firstView(df):
    df.columns = df.columns.str.lower()
    display('Размер набора данных (строк, столбцов):', df.shape)
    display('Количество грубых дубликатов в наборе данных:', df.duplicated().sum())
    display('Наименование столбцов:', df.columns)
    display('Просмотр типов данных в столбцах')
    df.info()
    display('')
    display('Вывод случайных 20 строк набора данных')
    display(df.sample(20))

# %%
df_firstView(logs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23cb292631d> in <module>
# ----> 1 df_firstView(logs)
#
# NameError: name 'logs' is not defined

# %% [markdown]
# Грубых дубликатов в наборе данных не обнаружено. Типы данных не вызывают вопросов. Пропусков не обнаружено.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Ок, данные в порядке.
# </div>

# %% [markdown]
# ## **Шаг 2. Проведение исследовательского анализа данных (EDA)**
# - Есть ли в наборе данных отсутствующие признаки, изучить средние значения и стандартные отклонения;
# - Посмотреть на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался;
# - Построить столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток);
# - Построить матрицу корреляций и отобразите её.<a id="step6"></a>
# </div>

# %% [markdown]
# **Есть ли в наборе данных отсутствующие признаки? изучить средние значения и стандартные отклонения.**

# %%
display('Описание признаков и целевой перменной:')
display(logs.describe().T)
# Out:
# 'Описание признаков и целевой перменной:'
#                                     count        mean        std        min        25%         50%         75%         max
# gender                             4000.0    0.510250   0.499957   0.000000   0.000000    1.000000    1.000000    1.000000
# near_location                      4000.0    0.845250   0.361711   0.000000   1.000000    1.000000    1.000000    1.000000
# partner                            4000.0    0.486750   0.499887   0.000000   0.000000    0.000000    1.000000    1.000000
# promo_friends                      4000.0    0.308500   0.461932   0.000000   0.000000    0.000000    1.000000    1.000000
# phone                              4000.0    0.903500   0.295313   0.000000   1.000000    1.000000    1.000000    1.000000
# contract_period                    4000.0    4.681250   4.549706   1.000000   1.000000    1.000000    6.000000   12.000000
# ...

# %% [markdown]
# Отсутствующих признаков не обнаружено.

# %% [markdown]
# **Посмотрим на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался.**

# %%
display('те, кто ушел в отток:')
display(logs[logs['churn']==1].describe().T)
display('те, кто остался:')
display(logs[logs['churn']==0].describe().T)
# Out:
# 'те, кто ушел в отток:'
#                                     count        mean        std        min        25%         50%         75%         max
# gender                             1061.0    0.510839   0.500118   0.000000   0.000000    1.000000    1.000000    1.000000
# near_location                      1061.0    0.768143   0.422217   0.000000   1.000000    1.000000    1.000000    1.000000
# partner                            1061.0    0.355325   0.478837   0.000000   0.000000    0.000000    1.000000    1.000000
# promo_friends                      1061.0    0.183789   0.387495   0.000000   0.000000    0.000000    0.000000    1.000000
# phone                              1061.0    0.902922   0.296204   0.000000   1.000000    1.000000    1.000000    1.000000
# contract_period                    1061.0    1.728558   2.132371   1.000000   1.000000    1.000000    1.000000   12.000000
# ...

# %% [markdown]
# <div class="alert alert-block alert-info">
# Или так: logs.groupby('churn').mean()
# </div>

# %% [markdown]
# Наблюдения по средним значениям:
# - Распределение по полу без перекосов в какую-либо сторону;
# - Большинство клиентов живет или работает рядом с фитнес-клубом;
# - Около 30% клиентов пришли по программе "Приведи друга";
# - Известны мобильные номера примерно 90% клиентов;
# - Средняя длительность абонементов клиентов - 4.6 месяцев;
# - Около 40% клиентов посещают групповые занятия;
# - Средний возраст клиентов 29 лет;
# - Средний срок до окончания договора - 4.3 месяцев;
# - Среднее время с момента первого обращения в фитнес-центр - 3.7 месяцев;
# - Средняя частота посещений за все время - 1.87 раз в неделю;
# - Средняя частота посещений за последний месяц - 1.76 раз в неделю.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Да, выводы верные.
# </div>
#
# <div class="alert alert-block alert-info">
# Чем отличаются группы, судя по средним значениям признаков?
# </div>

# %% [markdown]
# **Построим столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)**

# %%
left = logs[logs['churn']==1]
stay = logs[logs['churn']==0]
distplot_columns = ['avg_additional_charges_total', 'avg_class_frequency_total', 
                        'avg_class_frequency_current_month', 'lifetime', 'age', 
                        'contract_period', 'month_to_end_contract']
for column in distplot_columns: 
  plt.figure(figsize=(18,4)) 
  plt.title(column)
  sns.distplot(left[column], color="green")
  sns.distplot(stay[column], color="blue")
  plt.legend(['те, кто ушел в отток', 'те, кто остался'])
  plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# Для непрерывных признаков построенные графики подходят отлично – на них изображены **кривые плотностей** распределений.
#
# </div>
#
# <div class="alert alert-block alert-info">
#
# Для дискретных признаков month_to_end_contract, contract_period, а также для бинарных признаков (ниже) больше бы подошли **гистограммы плотностей (нормированные гистограммы)**. Гистограммы частот (ниже) неудобно сравнивать, так как число объектов в группах с churn=0 и churn=1 отличается. **Площадь** каждого столбика гистограмм плотностей равна **доле** объектов выборки со значением признака в соответствующем интервале, суммарная площадь всех столбиков равна 1. Если задать ширину столбиков, равной 1, то высоты столбиков (а не только площади) будут равны доле объектов выборки с соответствующими значениями.
#
# Гистограммы плотностей можно построить, например, так: sns.distplot(..., kde=False, norm_hist=True, bins=...). Границы столбиков bins стоит задавать одинаковыми для обеих групп, пример кода см. ниже.
#
#     min_value = int(min(gym['month_to_end_contract']))
#     max_value = int(max(gym['month_to_end_contract']))
#     sns.distplot(gym[gym['churn']==0]['month_to_end_contract'], kde=False, norm_hist=True, bins = range(min_value, max_value+2), label='0')
#     sns.distplot(gym[gym['churn']==1]['month_to_end_contract'], kde=False, norm_hist=True, bins = range(min_value, max_value+2), label='1')
#     plt.legend()
#
# Либо можно использовать go.Histogram(…, histnorm=‘probability’).
#
# </div>

# %%
for column in logs.columns:
  if column not in distplot_columns:
    logs.groupby('churn')[column].hist()
    plt.title(column)
    plt.legend(['те, кто ушел в отток', 'те, кто остался'])
    plt.show()

# %% [markdown]
# Гистограммы подтверждают наблюдения на основе средних значений, основаня масса оттока - клиенты с абонементами на срок 1 месяц и имеют период взаимодействия с клубом 0-1 месяцев.

# %% [markdown]
# **Построим матрицу корреляций и отобразите её.**

# %%
plt.figure(figsize=(14,10))
sns.heatmap(data = logs.corr(), annot=True, square=True, cmap = "YlGnBu")
plt.title('Матрица корреляций')
plt.show()

# %% [markdown]
# Видна сильная корреляция между признаками:
# - contract_period/month_to_end_contract,
# - avg_class_frequency_total/avg_class_frequency_current_month
#
# Связь признаков с churn очень слабая, наиболее проявлятся обратная корреляция с признаками avg_class_frequency_current_month -0.38 (поэтому логично ее не удалять), lifetime (-0.44), contract_period(-0.39) и month_to_end_contract (-0.38), age (-0,4).

# %% [markdown]
# <div class="alert alert-block alert-success">
# Матрица наглядная. Да, есть 2 пары признаков с очень высокой корреляцией.
# </div>
#
# <div class="alert alert-block alert-info">
# Числа можно было округлить до 2-3 знаков после запятой, например, так: sns.heatmap(..., fmt=...).
# </div>

# %% [markdown]
# ## **Шаг 3. Построим модель прогнозирования оттока пользователей**
#
# Построим модель бинарной классификации пользователей, где целевой признак — факт оттока пользователя в следующем месяце:
#
# - Разбить данные на обучающую и валидационную выборку;
# - Обучите модель на train-выборке двумя способами:
#     - логистической регрессией
#     - случайным лесом.
# - Оценить метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравнить по ним модели. Какая модель показала себя лучше на основании метрик?<a id="step7"></a>
# </div>

# %%
X = logs.drop('churn', axis = 1)
y = logs['churn']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# <div class="alert alert-block alert-success">
# Деление выборки на части проведено верно.
# </div>
#
# <div class="alert alert-block alert-info">
# Признаки можно было отмасштабировать.
# </div>

# %%
def print_all_metrics(y_true, y_pred, y_proba, title = 'Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.3f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.3f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.3f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.3f}'.format(f1_score(y_true, y_pred)))
    print('\tROC_AUC: {:.3f}'.format(roc_auc_score(y_true, y_proba)))

# %%
lr_model = LogisticRegression(random_state = 0)
lr_model.fit(X_train, y_train)
lr_predictions = lr_model.predict(X_test)
lr_probabilities = lr_model.predict_proba(X_test)[:,1]
print_all_metrics(y_test, lr_predictions, lr_probabilities , title='Метрики для модели логистической регрессии:')
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.925
# 	Precision: 0.863
# 	Recall: 0.828
# 	F1: 0.845
# 	ROC_AUC: 0.967

# %%
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0)
rf_model.fit(X_train, y_train)
rf_predictions = rf_model.predict(X_test)
rf_probabilities = rf_model.predict_proba(X_test)[:,1]
print_all_metrics(y_test, rf_predictions, rf_probabilities, title = 'Метрики для модели случайного леса:')
# Out:
# Метрики для модели случайного леса:
# 	Accuracy: 0.916
# 	Precision: 0.839
# 	Recall: 0.818
# 	F1: 0.829
# 	ROC_AUC: 0.968

# %% [markdown]
# Выводы по шагу:
# - модели значительно не отличаются, модель линейной регресси показала себя несколько лучше, чем случайного леса.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Верно, модель логистической регрессии показала лучшие результаты.
# </div>

# %% [markdown]
# Избавимся от сильно коррелирующих друг с другом признаков.

# %%
lr_model_test = LogisticRegression(random_state = 0)
X_train_cleared = X_train.drop(['avg_class_frequency_current_month', 'month_to_end_contract'], axis=1)
lr_model_test.fit(X_train_cleared, y_train)

log_reg = pd.DataFrame({'feature' : X_train_cleared.columns, 'coef' : lr_model_test.coef_[0]})
log_reg.sort_values(by='coef', ascending=True)
# Out:
#                          feature      coef
# 9                       lifetime -0.965818
# 6                   group_visits -0.640821
# 10     avg_class_frequency_total -0.613667
# 3                  promo_friends -0.458202
# 5                contract_period -0.266428
# 7                            age -0.200437
# 8   avg_additional_charges_total -0.004908
# 2                        partner -0.002670
# 1                  near_location  0.007011
# 4                          phone  0.075997
# 0                         gender  0.154482

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# Да, интересно посмотреть, как изменится качество модели при удалении признаков. Где значения accuracy,precision,recall модели lr_model_test на тестовой выборке?
#
# Сортировать признаки следует по **модулю** весов, так как именно модуль отвечает за важность признака.
# </div>

# %%
f_m = pd.DataFrame({'feature' : X_train.columns, 'importance' : rf_model.feature_importances_})
f_m.sort_values(by='importance', ascending=False)
# Out:
#                               feature  importance
# 10                           lifetime    0.276499
# 12  avg_class_frequency_current_month    0.180170
# 11          avg_class_frequency_total    0.129883
# 7                                 age    0.119129
# 8        avg_additional_charges_total    0.091473
# 9               month_to_end_contract    0.068855
# 5                     contract_period    0.065964
# 6                        group_visits    0.015652
# 0                              gender    0.012425
# 2                             partner    0.012285
# 3                       promo_friends    0.012053
# 1                       near_location    0.009421
# 4                               phone    0.006192

# %% [markdown]
# Так как мы выбрали модель линейной регресии исходя из значений метрик, буду ориентироваться по ней для формулировки вывода

# %% [markdown]
# ## **Шаг 4. Сделаем кластеризацию пользователей**
# <a id="step8"></a>
# </div>

# %% [markdown]
# **Стандартизием данные и построим матрицу расстояний на стандартизованной матрице признаков и нарисуем дендрограмму.**

# %%
sc = StandardScaler()
x_sc = sc.fit_transform(X)

linked = linkage(x_sc, method = 'ward')
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.title('Иерархия кластеров для клиентов сети фитнес центров')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# Дендрограмма построена корректно.
# </div>
#
# <div class="alert alert-block alert-info">
# Сколько можно выделить кластеров, судя по дендрограмме?
# </div>

# %%
# создадим матрицу расстояний
linked = linkage(x_sc, method = 'ward')
linked
# Out:
# array([[9.70000000e+01, 3.22200000e+03, 1.00990653e-01, 2.00000000e+00],
#        [2.61000000e+02, 3.17900000e+03, 1.22634574e-01, 2.00000000e+00],
#        [8.90000000e+02, 1.75000000e+03, 1.28123291e-01, 2.00000000e+00],
#        ...,
#        [7.98700000e+03, 7.99500000e+03, 8.38725499e+01, 2.65600000e+03],
#        [7.98800000e+03, 7.99600000e+03, 8.89563592e+01, 3.03400000e+03],
#        [7.99200000e+03, 7.99700000e+03, 1.04627601e+02, 4.00000000e+03]])

# %% [markdown]
# **Обучим модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5.**

# %%
km = KMeans(n_clusters = 5, random_state=0)
labels = km.fit_predict(x_sc)
df_clust_1 = logs
df_clust_1['cluster_km'] = labels

# %% [markdown]
# <div class="alert alert-block alert-success">
# Молодец, что задаешь random_state для воспроизводимости результатов кластеризации.
# </div>
#
# <div class="alert alert-block alert-info">
#
# В строке
#
#     df_clust_1 = logs
#
# копирования не происходит, все последующие изменения с df_clust_1 отразятся и на logs. Для копирования таблицы следует воспользоваться специальной функцией.
# </div>

# %% [markdown]
# **Посмотрим на средние значения признаков для кластеров. Можно ли сразу что-то заметить?**

# %%
df_clust_final = logs.copy(deep=True)
df_clust_grouped_mean = logs.groupby('cluster_km').agg('mean')
df_clust_grouped_mean
# Out:
#               gender  near_location   partner  promo_friends     phone  contract_period  group_visits        age  avg_additional_charges_total  month_to_end_contract  lifetime  avg_class_frequency_total  avg_class_frequency_current_month     churn
# cluster_km
# 0           0.502473       0.959446  0.783383       0.574679  1.000000        10.884273      0.543027  29.980218                    160.706969               9.950544  4.738872                   1.983305                           1.976225  0.027695
# 1           0.522078       0.862338  0.470130       0.306494  0.000000         4.787013      0.425974  29.301299                    143.957664               4.475325  3.924675                   1.847220                           1.716369  0.267532
# ...

# %% [markdown]
# Выводы по шагу:
# - Самая высокая доля оттока у 3-го кластера - 51%, у 2-го и 3-го кластеров - 44% и 27% соотвественно,
# - Самые надежные 4-ый и 0-ой кластер - 7% и 3%.

# %% [markdown]
# <div class="alert alert-block alert-success">
# Правильно, доля оттока – это по сути среднее значение признака churn в кластере.
# </div>

# %% [markdown]
# **Построим распределения признаков для кластеров. Можно ли что-то заметить по ним?**

# %%
non_binary = logs.drop(columns =(['gender', 'near_location', 
                              'partner','promo_friends', 'phone',
                              'group_visits', 'churn', 'cluster_km','contract_period', 'month_to_end_contract', 'lifetime']))
binary = logs[['gender', 'near_location', 
                              'partner','promo_friends', 'phone',
                              'group_visits', 'contract_period', 'month_to_end_contract', 'lifetime']]

# %%
for col in non_binary:
    plt.figure(figsize=(18,5))
    for i in range(0,5):
        sns.distplot(logs.query('cluster_km == @i')[col],
                    hist=False,
                    rug=True,
                    kde_kws={'label':'Кластер'+ str(i)})
plt.tight_layout()

# %% [markdown]
# <div class="alert alert-block alert-success">
# Графики замечательные.
# </div>
#
# <div class="alert alert-block alert-info">
# Где графики распределений для остальных признаков?
#
# Рекомендации для дискретных признаков те же, что и выше.
# </div>

# %% [markdown]
# Выводы по графикам:
# - Высокая склонность к оттоку по возрасту в районе 28 лет(3-й кластер), надежные кластеры самые возрастные 0-й кластер на пике 32 года, 4-й на пике 30 лет;
# - По дополнительным затратам более надежные кластеры имеют более широкий график, большинство клиентов 3-го тратят меньше, далее 2-й и 3-й кластер;
# - Самый активный кластер 4-й, в среднем 3 посещения в неделю. Минимальная активность наблюдается у 3-го кластера, в среднем 1 занятие в неделю. Чем клиент активнее в теченеии недели посещяет зал, тем меньше вероятность его оттока;
# - Месячная посещяемсоть, практически аналогична недельной.

# %% [markdown]
# ## **Шаг 5. Сформулируем выводы и сделаем базовые рекомендации по работе с клиентами**<a id="step9"></a>
# </div>

# %% [markdown]
# В представленном наборе данных грубых дубликатов не обнаружено, типы данных не вызвали вопросов, пропусков не обнаружено не было.
#
# Основная доля клиентов, которых клуб теряет:
# - приходят не по рекомендаций друзей (по акции "приведи друга" остаются надолго);
# - покупают самый короткий абонемент (1-3 месяца);
# - редко посещают групповые занятия;
# - тратят на дополнительные услуги меньше других клиентов;
# - ходят в спорт зал в среднем 1 раз в неделю.
#
# **Основные рекомендации:**
# - наибольшего внимания заслуживают новые клиентов, эти товарищи слишком легко уходят;
# - траты новых клиентов на пике выше всех остальных кластеров, для новых клиентов нужно создать акции и дополнительные скидки на первые 3 месяца для их удержания;
# - абонемент на месяц берут так же и для того чтобы разведать обстановку, подойдет/не подойдет зал, следует предложить скидочную программу на покупку 3 месячного и более абонемента для тех кто взял изначально на месяц;
# - необходимо разработать систему пробных занятий;
# - разработка корпоративных программ, так как хорошие результаты показывают кластеры с высокой долей клиентов для которых фитнес находится рядом с домом/работой и они купили абонемент по корпоративной цене;
# - постоянные клиенты имеют минимальную склонность к оттоку, для них нужна отдельная программа лояльности, для стимуляции покупать абонементы на 12 и более месяцев.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Итоговый комментарий:</b>
#
# Спасибо, ты провел великолепное исследование, так держать! :)
#
# </div>
